# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
os.environ['PYTHONPATH'] = ':'.join(sys.path)

# %%
import numpy as np
import hgpflow_v2.performance # don't know why this is needed, but it is
from hgpflow_v2.performance.performance import PerformanceCOCOA
from copy import deepcopy

# %% [markdown]
# ## HSS Samples

# %%
from hgpflow_v2.performance.performance import PerformanceCOCOA
from hgpflow_v2.performance.plot_helper_event import compute_jet_residual_dict, plot_jet_residuals

RUN = '/pscratch/sd/a/agolub/hgpflow_runs/hgpflow_v2/largeqqbartraining4nodev1epoch25'

perf = PerformanceCOCOA(
    truth_path='/pscratch/sd/a/agolub/hss_events/cocoa_hss_30k_test.root',
    pred_path=f'{RUN}/inference/hss/pred_*_merged.root',
    ind_threshold=0.4,
    event_number_offset=0)   # your splitter's -eo OFFSET for this file
# Out:
# ...
# Computing HGPFlow mass...: 100%|██████████| 29976/29976 [00:00<00:00, 31477.48it/s]
# E, pT will be scaled by 0.001
# no pflow_* branches in this file -> skipping PPflow baseline
# ...
# Applying fiducial cuts...: 100%|██████████| 30000/30000 [00:00<00:00, 112685.28it/s]
# /global/u1/a/agolub/HGPflow/hgpflow_v2/performance/reader.py:178: RuntimeWarning: invalid value encountered in sqrt
#   truth_dict['particle_mass'].append(np.sqrt(e**2 - p**2))
# common event count: 29976
# ...
# Filtering and reordering HGPFlow...: 100%|██████████| 12/12 [00:00<00:00, 2198.08it/s]

# %%
# Proxy comparison instead of ppflow as the comparison curve
perf.compute_jets(radius=0.4, algo='antikt')
perf.match_jets()
residual_dict = compute_jet_residual_dict({
    'hgpflow': perf.hgpflow_dict['matched_hgpflow_jets'],
    'proxy'  : perf.hgpflow_dict['matched_proxy_jets'],
})
# Out:
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# truth
# Computing jets...:   0%|          | 21/29976 [00:00<06:47, 73.47it/s]
# #--------------------------------------------------------------------------
# #                         FastJet release 3.5.1
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           https://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# Computing jets...: 100%|██████████| 29976/29976 [01:49<00:00, 273.51it/s]
# proxy
# ...

# %%
fig = plot_jet_residuals(residual_dict, pt_relative=True)

# %%
perf.hgpflow_dict['hgpflow_eta'] = perf.hgpflow_dict['proxy_eta']
perf.hgpflow_dict['hgpflow_phi'] = perf.hgpflow_dict['proxy_phi']

for i in range(len(perf.hgpflow_dict['hgpflow_pt'])):
    ch_mask = perf.hgpflow_dict['hgpflow_class'][i] <= 2
    perf.hgpflow_dict['hgpflow_pt'][i][ch_mask] = perf.hgpflow_dict['proxy_pt'][i][ch_mask]

# %%
perf.compute_jets(n_procs=30)
perf.match_jets()
# Out:
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# truth
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# Computing jets...:   0%|          | 0/333 [00:00<?, ?it/s]
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# Computing jets...:   0%|          | 0/333 [00:00<?, ?it/s]
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# Computing jets...:   0%|          | 0/334 [00:00<?, ?it/s]47.77it/s]
# Jet clustering algorithm:
# Computing jets...:   4%|▎         | 12/333 [00:00<00:02, 118.42it/s]
#  antikt
# Jet clustering radius:  0.4
# Computing jets...:  10%|▉         | 32/333 [00:00<00:02, 148.68it/s]
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# Computing jets...:   6%|▌         | 20/333 [00:00<00:01, 191.68it/s]
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# ...
# Computing jets...:  13%|█▎        | 43/333 [00:00<00:01, 210.89it/s]
# ...

# %%
from hgpflow_v2.performance.plot_helper_event import compute_jet_residual_dict

_dict = {
    'ppflow': perf.truth_dict['matched_ppflow_jets'],
    'hgpflow': perf.hgpflow_dict['matched_hgpflow_jets'],
}

jet_residual_dict = compute_jet_residual_dict(_dict, dr_cut=0.1, leading_N_jets=2, pt_min=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
#       1 from hgpflow_v2.performance.plot_helper_event import compute_jet_residual_dict
#       3 _dict = {
# ----> 4     'ppflow': perf.truth_dict['matched_ppflow_jets'],
#       5     'hgpflow': perf.hgpflow_dict['matched_hgpflow_jets'],
#       6 }
#       8 jet_residual_dict = compute_jet_residual_dict(_dict, dr_cut=0.1, leading_N_jets=2, pt_min=10)
#
# KeyError: 'matched_ppflow_jets'

# %% [markdown]
# ## Testing LLP jets only

# %%
from hgpflow_v2.performance.performance import PerformanceCOCOA
from hgpflow_v2.performance.llp_helper import tag_truth_jets_llp, select_matched_by_llp, llp_frac_summary
from hgpflow_v2.performance.plot_helper_event import compute_jet_residual_dict, plot_jet_residuals
import numpy as np

RUN = '/pscratch/sd/a/agolub/hgpflow_runs/hgpflow_v2/largeqqbartraining4nodev1epoch25'
perf = PerformanceCOCOA(
    truth_path='/pscratch/sd/a/agolub/HSS_events_with_ppflow/cocoa_hss_pflow_30k.root',
    pred_path=f'{RUN}/inference/hss_ppflow/pred_*_merged.root',
    ind_threshold=0.4, event_number_offset=0,
    llp_lxy_mm=10)                                   # <-- displacement threshold [mm]

# alignment guard — expect ~0.92
ts = np.array([x.sum() for x in perf.truth_dict['particle_pt']])
hs = np.array([x.sum() for x in perf.hgpflow_dict['hgpflow_pt']])
print('alignment corr:', np.corrcoef(ts, hs)[0,1].round(3))

perf.compute_jets(radius=0.4, algo='antikt', store_constituent_idxs=True)  # MUST be True
perf.match_jets()
tag_truth_jets_llp(perf)          # computes .llp_frac once
llp_frac_summary(perf)            # distribution + counts, to choose the cut
# Out:
# ...
# Computing HGPFlow mass...: 100%|██████████| 29976/29976 [00:00<00:00, 52987.31it/s]
# E, pT will be scaled by 0.001
# ...
# Applying fiducial cuts...: 100%|██████████| 30000/30000 [00:00<00:00, 71085.20it/s]
# /global/u1/a/agolub/HGPflow/hgpflow_v2/performance/reader.py:196: RuntimeWarning: invalid value encountered in sqrt
#   truth_dict['particle_mass'].append(np.sqrt(e**2 - p**2))
# /global/u1/a/agolub/HGPflow/hgpflow_v2/performance/reader.py:204: RuntimeWarning: invalid value encountered in sqrt
#   truth_dict['pflow_mass'].append(np.sqrt(e**2 - p**2))
# common event count: 29976
# ...
# Filtering and reordering HGPFlow...: 100%|██████████| 12/12 [00:00<00:00, 2803.68it/s]
# alignment corr: 0.922
# Jet clustering algorithm:  antikt
# Jet clustering radius:  0.4
# truth
# Computing jets...:   0%|          | 5/29976 [00:00<10:02, 49.78it/s]
# #--------------------------------------------------------------------------
# #                         FastJet release 3.5.1
# ...

# %%
perf.hgpflow_dict.keys()
# Out:
# dict_keys(['pred_ind', 'proxy_pt', 'proxy_eta', 'proxy_phi', 'hgpflow_pt', 'hgpflow_eta', 'hgpflow_phi', 'hgpflow_class', 'event_number', 'hgpflow_mass', 'hgpflow_e', 'hgpflow_charge', 'proxy_jets', 'jets', 'matched_proxy_jets', 'matched_hgpflow_jets'])

# %%
# ---- the plot; FRAC is the single knob to scan ----
FRAC = 0.9
res = compute_jet_residual_dict({
    'hgpflow': select_matched_by_llp(perf.hgpflow_dict['matched_hgpflow_jets'], FRAC, keep='llp'),
    'ppflow': select_matched_by_llp(perf.truth_dict['matched_ppflow_jets'], FRAC, keep='llp'),
    'proxy'  : select_matched_by_llp(perf.hgpflow_dict['matched_proxy_jets'],   FRAC, keep='llp'),
})
fig = plot_jet_residuals(res, pt_relative=True)
fig.savefig(f'jet_residuals_hss_llp{int(FRAC*100)}.png', dpi=150, bbox_inches='tight')

# %%
from hgpflow_v2.performance.llp_helper import (
    tag_truth_jets_llp, select_matched_by_llp, llp_frac_summary, llp_efficiency_summary)

# (perf already built with llp_lxy_mm=10, compute_jets(store_constituent_idxs=True),
#  match_jets(), tag_truth_jets_llp(perf) — see previous cell)

# one-call fair comparison (the table from above):
llp_efficiency_summary(perf, frac=0.9, comp='hgpflow')

# score the stage-1 proxy the same way, to see what stage 2 adds on LLP jets:
llp_efficiency_summary(perf, frac=0.9, comp='proxy')

llp_efficiency_summary(perf, frac=0.9, comp="ppflow")

# scan the LLP-fraction cut:
for FRAC in [0.1, 0.5, 0.9]:
    llp_efficiency_summary(perf, frac=FRAC, comp='hgpflow')
# Out:
# --- hgpflow jets | LLP cut llp_frac >= 0.9 | match dr < 0.1 ---
#    pT bin |  LLP eff  LLP med  LLP IQR |  prm eff  prm med  prm IQR
#   20-30   |   29.0%   -0.062    0.350 |   79.4%   -0.009    0.194
#   30-50   |   35.4%   -0.076    0.311 |   84.7%   +0.005    0.186
#   50-80   |   45.2%   -0.062    0.260 |   96.6%   +0.032    0.174
#   80-150  |   46.4%   -0.048    0.280 |   98.7%   +0.052    0.171
# --- proxy jets | LLP cut llp_frac >= 0.9 | match dr < 0.1 ---
#    pT bin |  LLP eff  LLP med  LLP IQR |  prm eff  prm med  prm IQR
#   20-30   |   31.5%   -0.173    0.390 |   80.2%   -0.069    0.217
#   30-50   |   36.5%   -0.234    0.314 |   85.5%   -0.057    0.204
#   50-80   |   45.0%   -0.274    0.205 |   96.8%   -0.038    0.174
#   80-150  |   46.4%   -0.267    0.163 |   98.9%   -0.022    0.154
# --- ppflow jets | LLP cut llp_frac >= 0.9 | match dr < 0.1 ---
#    pT bin |  LLP eff  LLP med  LLP IQR |  prm eff  prm med  prm IQR
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def llp_binned_arrays(perf, frac=0.9, comp='hgpflow', dr_cut=0.1,
                      pt_bins=np.array([20,30,50,80,150]), eta_max=2.5):
    key = {'hgpflow':'matched_hgpflow_jets','proxy':'matched_proxy_jets'}[comp]
    matched = perf.hgpflow_dict[key]
    centers = 0.5*(pt_bins[:-1]+pt_bins[1:])
    out = {}
    for keep in ('llp','prompt'):
        ref_ev, comp_ev = select_matched_by_llp(matched, frac, keep=keep)
        # flatten to per-jet arrays
        rpt  = np.array([r.pt for refs in ref_ev for r in refs])
        reta = np.array([abs(r.eta) for refs in ref_ev for r in refs])
        dR   = np.array([r.delta_R(c) for refs,comps in zip(ref_ev,comp_ev) for r,c in zip(refs,comps)])
        rel  = np.array([(c.pt-r.pt)/r.pt for refs,comps in zip(ref_ev,comp_ev) for r,c in zip(refs,comps)])
        fid  = reta < eta_max
        eff, med, iqr = [], [], []
        for lo,hi in zip(pt_bins[:-1], pt_bins[1:]):
            b = fid & (rpt>=lo) & (rpt<hi)
            m = b & (dR < dr_cut)
            eff.append(m.sum()/b.sum() if b.sum() else np.nan)
            med.append(np.median(rel[m]) if m.sum() else np.nan)
            iqr.append((np.percentile(rel[m],75)-np.percentile(rel[m],25)) if m.sum() else np.nan)
        out[keep] = dict(centers=centers, eff=np.array(eff), med=np.array(med), iqr=np.array(iqr))
    return out

d = llp_binned_arrays(perf, frac=0.9)
fig, (a1, a2) = plt.subplots(1, 2, figsize=(12,4.5))
for keep, c in [('llp','firebrick'), ('prompt','gray')]:
    a1.plot(d[keep]['centers'], d[keep]['eff'], 'o-', color=c, label=f'{keep} jets')
    a2.errorbar(d[keep]['centers'], d[keep]['med'], yerr=d[keep]['iqr']/2, fmt='o-', color=c, label=f'{keep} jets')
a1.set(xlabel='truth jet $p_T$ [GeV]', ylabel='matching efficiency (ΔR<0.1)', ylim=(0,1.05)); a1.legend(); a1.grid(alpha=.3)
a2.axhline(0, ls='--', c='k', lw=1)
a2.set(xlabel='truth jet $p_T$ [GeV]', ylabel='$(p_T^{reco}-p_T^{truth})/p_T^{truth}$ (median ± IQR/2)'); a2.legend(); a2.grid(alpha=.3)
fig.suptitle('HGPflow on LLP vs prompt jets (HSS)'); fig.tight_layout()
fig.savefig('hss_llp_vs_prompt_vs_pt.png', dpi=150, bbox_inches='tight')

# %%
from hgpflow_v2.performance.llp_helper import tag_truth_jets_llp, plot_llp_comparison

# (perf already built with llp_lxy_mm=10, compute_jets(store_constituent_idxs=True),
#  match_jets(), tag_truth_jets_llp(perf) — same prerequisites as before)

fig, summaries = plot_llp_comparison(perf, frac=0.9)
